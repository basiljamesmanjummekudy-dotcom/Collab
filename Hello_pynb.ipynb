# %% [markdown]
# <a href="https://colab.research.google.com/github/basiljamesmanjummekudy-dotcom/Collab/blob/main/Hello_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
M

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello123")
# Out:
# Hello123

# %%
print("Hello 1112")
# Out:
# Hello 1112
